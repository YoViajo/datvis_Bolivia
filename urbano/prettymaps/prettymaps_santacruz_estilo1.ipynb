# %%
# !pip install git+https://github.com/marceloprates/prettymaps.git
# Out:
# Collecting vsketch
#   Cloning https://github.com/abey79/vsketch to /tmp/pip-install-4pyi387f/vsketch_774b8886952443959c88b4c4ae7db8fb
#   Running command git clone --filter=blob:none --quiet https://github.com/abey79/vsketch /tmp/pip-install-4pyi387f/vsketch_774b8886952443959c88b4c4ae7db8fb
#   Resolved https://github.com/abey79/vsketch to commit 1f28fa8fa491a574d04cbe80ae82f61e3b3d17fb
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting vpype[all]@ git+https://github.com/abey79/vpype@e8aab428b6790de03e36cd51aa30ca0612a38d87
#   Cloning https://github.com/abey79/vpype (to revision e8aab428b6790de03e36cd51aa30ca0612a38d87) to /tmp/pip-install-4pyi387f/vpype_e5dce66323ef4947b860f57a6eee70e4
#   Running command git clone --filter=blob:none --quiet https://github.com/abey79/vpype /tmp/pip-install-4pyi387f/vpype_e5dce66323ef4947b860f57a6eee70e4
#   Running command git rev-parse -q --verify 'sha^e8aab428b6790de03e36cd51aa30ca0612a38d87'
#   Running command git fetch -q https://github.com/abey79/vpype e8aab428b6790de03e36cd51aa30ca0612a38d87
#   Running command git checkout -q e8aab428b6790de03e36cd51aa30ca0612a38d87
#   Resolved https://github.com/abey79/vpype to commit e8aab428b6790de03e36cd51aa30ca0612a38d87
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting colorama<0.5.0,>=0.4.4
#   Using cached colorama-0.4.4-py2.py3-none-any.whl (16 kB)
# Collecting bezier>=2021.2.12
#   Downloading bezier-2021.2.12.tar.gz (313 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.9/313.9 KB 1.2 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> [1 lines of output]
#       The BEZIER_INSTALL_PREFIX environment variable must be set.
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
# Collecting git+https://github.com/marceloprates/prettymaps.git
#   Cloning https://github.com/marceloprates/prettymaps.git to /tmp/pip-req-build-vazjf36f
#   Running command git clone --filter=blob:none --quiet https://github.com/marceloprates/prettymaps.git /tmp/pip-req-build-vazjf36f
#   Resolved https://github.com/marceloprates/prettymaps.git to commit 72fd33ce5f075020ea272e80df906c64c53d4d93
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: osmnx==1.0.1 in /home/yoviajo/anaconda3/envs/geo_env/lib/python3.10/site-packages (from prettymaps==0.1.3) (1.0.1)
# Requirement already satisfied: tabulate==0.8.9 in /home/yoviajo/anaconda3/envs/geo_env/lib/python3.10/site-packages (from prettymaps==0.1.3) (0.8.9)
# Requirement already satisfied: networkx>=2.5 in /home/yoviajo/anaconda3/envs/geo_env/lib/python3.10/site-packages (from osmnx==1.0.1->prettymaps==0.1.3) (2.6.3)
# Requirement already satisfied: geopandas>=0.8 in /home/yoviajo/anaconda3/envs/geo_env/lib/python3.10/site-packages (from osmnx==1.0.1->prettymaps==0.1.3) (0.10.2)
# Requirement already satisfied: pandas>=1.1 in /home/yoviajo/anaconda3/envs/geo_env/lib/python3.10/site-packages (from osmnx==1.0.1->prettymaps==0.1.3) (1.4.0)
# Requirement already satisfied: descartes>=1.1 in /home/yoviajo/anaconda3/envs/geo_env/lib/python3.10/site-packages (from osmnx==1.0.1->prettymaps==0.1.3) (1.1.0)
# Requirement already satisfied: Rtree>=0.9 in /home/yoviajo/anaconda3/envs/geo_env/lib/python3.10/site-packages (from osmnx==1.0.1->prettymaps==0.1.3) (0.9.7)
# Requirement already satisfied: matplotlib>=3.3 in /home/yoviajo/anaconda3/envs/geo_env/lib/python3.10/site-packages (from osmnx==1.0.1->prettymaps==0.1.3) (3.5.1)
# Requirement already satisfied: pyproj>=2.6 in /home/yoviajo/anaconda3/envs/geo_env/lib/python3.10/site-packages (from osmnx==1.0.1->prettymaps==0.1.3) (3.3.0)
# Requirement already satisfied: Shapely>=1.7 in /home/yoviajo/anaconda3/envs/geo_env/lib/python3.10/site-packages (from osmnx==1.0.1->prettymaps==0.1.3) (1.8.0)
# Requirement already satisfied: requests>=2.25 in /home/yoviajo/anaconda3/envs/geo_env/lib/python3.10/site-packages (from osmnx==1.0.1->prettymaps==0.1.3) (2.27.1)
# Requirement already satisfied: numpy>=1.19 in /home/yoviajo/anaconda3/envs/geo_env/lib/python3.10/site-packages (from osmnx==1.0.1->prettymaps==0.1.3) (1.22.1)
# Requirement already satisfied: fiona>=1.8 in /home/yoviajo/anaconda3/envs/geo_env/lib/python3.10/site-packages (from geopandas>=0.8->osmnx==1.0.1->prettymaps==0.1.3) (1.8.20)
# Requirement already satisfied: fonttools>=4.22.0 in /home/yoviajo/anaconda3/envs/geo_env/lib/python3.10/site-packages (from matplotlib>=3.3->osmnx==1.0.1->prettymaps==0.1.3) (4.29.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/yoviajo/anaconda3/envs/geo_env/lib/python3.10/site-packages (from matplotlib>=3.3->osmnx==1.0.1->prettymaps==0.1.3) (1.3.2)
# Requirement already satisfied: pillow>=6.2.0 in /home/yoviajo/anaconda3/envs/geo_env/lib/python3.10/site-packages (from matplotlib>=3.3->osmnx==1.0.1->prettymaps==0.1.3) (9.0.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/yoviajo/anaconda3/envs/geo_env/lib/python3.10/site-packages (from matplotlib>=3.3->osmnx==1.0.1->prettymaps==0.1.3) (3.0.7)
# Requirement already satisfied: cycler>=0.10 in /home/yoviajo/anaconda3/envs/geo_env/lib/python3.10/site-packages (from matplotlib>=3.3->osmnx==1.0.1->prettymaps==0.1.3) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/yoviajo/anaconda3/envs/geo_env/lib/python3.10/site-packages (from matplotlib>=3.3->osmnx==1.0.1->prettymaps==0.1.3) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in /home/yoviajo/anaconda3/envs/geo_env/lib/python3.10/site-packages (from matplotlib>=3.3->osmnx==1.0.1->prettymaps==0.1.3) (21.3)
# Requirement already satisfied: pytz>=2020.1 in /home/yoviajo/anaconda3/envs/geo_env/lib/python3.10/site-packages (from pandas>=1.1->osmnx==1.0.1->prettymaps==0.1.3) (2021.3)
# Requirement already satisfied: certifi in /home/yoviajo/anaconda3/envs/geo_env/lib/python3.10/site-packages (from pyproj>=2.6->osmnx==1.0.1->prettymaps==0.1.3) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/yoviajo/anaconda3/envs/geo_env/lib/python3.10/site-packages (from requests>=2.25->osmnx==1.0.1->prettymaps==0.1.3) (1.26.8)
# Requirement already satisfied: idna<4,>=2.5 in /home/yoviajo/anaconda3/envs/geo_env/lib/python3.10/site-packages (from requests>=2.25->osmnx==1.0.1->prettymaps==0.1.3) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/yoviajo/anaconda3/envs/geo_env/lib/python3.10/site-packages (from requests>=2.25->osmnx==1.0.1->prettymaps==0.1.3) (2.0.11)
# Requirement already satisfied: click-plugins>=1.0 in /home/yoviajo/anaconda3/envs/geo_env/lib/python3.10/site-packages (from fiona>=1.8->geopandas>=0.8->osmnx==1.0.1->prettymaps==0.1.3) (1.1.1)
# Requirement already satisfied: click>=4.0 in /home/yoviajo/anaconda3/envs/geo_env/lib/python3.10/site-packages (from fiona>=1.8->geopandas>=0.8->osmnx==1.0.1->prettymaps==0.1.3) (8.0.3)
# Requirement already satisfied: cligj>=0.5 in /home/yoviajo/anaconda3/envs/geo_env/lib/python3.10/site-packages (from fiona>=1.8->geopandas>=0.8->osmnx==1.0.1->prettymaps==0.1.3) (0.7.2)
# Requirement already satisfied: six>=1.7 in /home/yoviajo/anaconda3/envs/geo_env/lib/python3.10/site-packages (from fiona>=1.8->geopandas>=0.8->osmnx==1.0.1->prettymaps==0.1.3) (1.16.0)
# Requirement already satisfied: setuptools in /home/yoviajo/anaconda3/envs/geo_env/lib/python3.10/site-packages (from fiona>=1.8->geopandas>=0.8->osmnx==1.0.1->prettymaps==0.1.3) (60.7.1)
# Requirement already satisfied: attrs>=17 in /home/yoviajo/anaconda3/envs/geo_env/lib/python3.10/site-packages (from fiona>=1.8->geopandas>=0.8->osmnx==1.0.1->prettymaps==0.1.3) (21.4.0)
# Requirement already satisfied: munch in /home/yoviajo/anaconda3/envs/geo_env/lib/python3.10/site-packages (from fiona>=1.8->geopandas>=0.8->osmnx==1.0.1->prettymaps==0.1.3) (2.5.0)

# %%
#!mkdir ~/salida
#!mkdir ~/assets
#!mkdir ~/assets/Permanent_Marker/
#!wget -O ~/assets/Permanent_Marker/PermanentMarker-Regular.ttf https://github.com/marceloprates/prettymaps/raw/main/assets/Permanent_Marker/PermanentMarker-Regular.ttf
# Out:
# --2022-02-17 10:13:04--  https://github.com/marceloprates/prettymaps/raw/main/assets/Permanent_Marker/PermanentMarker-Regular.ttf
# Resolviendo github.com (github.com)... 140.82.114.3
# Conectando con github.com (github.com)[140.82.114.3]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 302 Found
# Ubicación: https://raw.githubusercontent.com/marceloprates/prettymaps/main/assets/Permanent_Marker/PermanentMarker-Regular.ttf [siguiente]
# --2022-02-17 10:13:05--  https://raw.githubusercontent.com/marceloprates/prettymaps/main/assets/Permanent_Marker/PermanentMarker-Regular.ttf
# Resolviendo raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.108.133, ...
# Conectando con raw.githubusercontent.com (raw.githubusercontent.com)[185.199.110.133]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 73620 (72K) [application/octet-stream]
# Guardando como: “../assets/Permanent_Marker/PermanentMarker-Regular.ttf”
#
# ../assets/Permanent 100%[===================>]  71,89K  --.-KB/s    en 0,05s
#
# 2022-02-17 10:13:05 (1,33 MB/s) - “../assets/Permanent_Marker/PermanentMarker-Regular.ttf” guardado [73620/73620]

# %%
# Prettymaps
from prettymaps import *
from matplotlib import pyplot as plt

# %%
# Init matplotlib figure
fig, ax = plt.subplots(figsize = (12, 12), constrained_layout = True)

backup = plot(
    # Address:
    'Plaza 24 de Septiembre, Santa Cruz, Bolivia',
    # Plot geometries in a circle of radius:
    radius = 1500,
    # Matplotlib axis
    ax = ax,
    # Which OpenStreetMap layers to plot and their parameters:
    layers = {
            # Perimeter (in this case, a circle)
            'perimeter': {},
            # Streets and their widths
            'streets': {
                'width': {
                    'motorway': 5,
                    'trunk': 5,
                    'primary': 4.5,
                    'secondary': 4,
                    'tertiary': 3.5,
                    'residential': 3,
                    'service': 2,
                    'unclassified': 2,
                    'pedestrian': 2,
                    'footway': 1,
                }
            },
            # Other layers:
            #   Specify a name (for example, 'building') and which OpenStreetMap tags to fetch
            'building': {'tags': {'building': True, 'landuse': 'construction'}, 'union': False},
            'water': {'tags': {'natural': ['water', 'bay']}},
            'green': {'tags': {'landuse': 'grass', 'natural': ['island', 'wood'], 'leisure': 'park'}},
            'forest': {'tags': {'landuse': 'forest'}},
            'parking': {'tags': {'amenity': 'parking', 'highway': 'pedestrian', 'man_made': 'pier'}}
        },
        # drawing_kwargs:
        #   Reference a name previously defined in the 'layers' argument and specify matplotlib parameters to draw it
        drawing_kwargs = {
            'background': {'fc': '#F2F4CB', 'ec': '#dadbc1', 'hatch': 'ooo...', 'zorder': -1},
            'perimeter': {'fc': '#F2F4CB', 'ec': '#dadbc1', 'lw': 0, 'hatch': 'ooo...',  'zorder': 0},
            'green': {'fc': '#D0F1BF', 'ec': '#2F3737', 'lw': 1, 'zorder': 1},
            'forest': {'fc': '#64B96A', 'ec': '#2F3737', 'lw': 1, 'zorder': 1},
            'water': {'fc': '#a1e3ff', 'ec': '#2F3737', 'hatch': 'ooo...', 'hatch_c': '#85c9e6', 'lw': 1, 'zorder': 2},
            'parking': {'fc': '#F2F4CB', 'ec': '#2F3737', 'lw': 1, 'zorder': 3},
            'streets': {'fc': '#2F3737', 'ec': '#475657', 'alpha': 1, 'lw': 0, 'zorder': 3},
            'building': {'palette': ['#FFC857', '#E9724C', '#C5283D'], 'ec': '#2F3737', 'lw': .5, 'zorder': 4},
        }
)

plt.savefig('~/salida/santacruz_e1.png')
plt.savefig('~/salida/santacruz_e1.svg')
# Out:
# /home/yoviajo/anaconda3/envs/geo_env/lib/python3.10/site-packages/osmnx/utils_geo.py:280: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for polygon in geometry:
# /home/yoviajo/anaconda3/envs/geo_env/lib/python3.10/site-packages/osmnx/utils_geo.py:374: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for poly in multipoly:
# /home/yoviajo/anaconda3/envs/geo_env/lib/python3.10/site-packages/osmnx/utils_geo.py:374: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for poly in multipoly:
# /home/yoviajo/anaconda3/envs/geo_env/lib/python3.10/site-packages/prettymaps/fetch.py:317: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   list(lines)
# /home/yoviajo/anaconda3/envs/geo_env/lib/python3.10/site-packages/prettymaps/fetch.py:317: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   list(lines)
# /home/yoviajo/anaconda3/envs/geo_env/lib/python3.10/site-packages/osmnx/utils_geo.py:280: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for polygon in geometry:
# /home/yoviajo/anaconda3/envs/geo_env/lib/python3.10/site-packages/osmnx/geometries.py:798: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   for merged_inner_linestring in list(merged_inner_linestrings):
# /home/yoviajo/anaconda3/envs/geo_env/lib/python3.10/site-packages/osmnx/geometries.py:798: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for merged_inner_linestring in list(merged_inner_linestrings):
# /home/yoviajo/anaconda3/envs/geo_env/lib/python3.10/site-packages/osmnx/geometries.py:787: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   for merged_outer_linestring in list(merged_outer_linestrings):
# /home/yoviajo/anaconda3/envs/geo_env/lib/python3.10/site-packages/osmnx/geometries.py:787: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for merged_outer_linestring in list(merged_outer_linestrings):
# /home/yoviajo/anaconda3/envs/geo_env/lib/python3.10/site-packages/osmnx/utils_geo.py:374: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for poly in multipoly:
# /home/yoviajo/anaconda3/envs/geo_env/lib/python3.10/site-packages/prettymaps/fetch.py:222: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   multipolys = reduce(lambda x,y: x+y, [list(x) for x in multipolys]) if len(multipolys) > 0 else []
# /home/yoviajo/anaconda3/envs/geo_env/lib/python3.10/site-packages/prettymaps/fetch.py:222: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   multipolys = reduce(lambda x,y: x+y, [list(x) for x in multipolys]) if len(multipolys) > 0 else []
# /home/yoviajo/anaconda3/envs/geo_env/lib/python3.10/site-packages/osmnx/utils_geo.py:280: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for polygon in geometry:
# /home/yoviajo/anaconda3/envs/geo_env/lib/python3.10/site-packages/osmnx/utils_geo.py:374: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for poly in multipoly:
# /home/yoviajo/anaconda3/envs/geo_env/lib/python3.10/site-packages/osmnx/utils_geo.py:280: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for polygon in geometry:
# /home/yoviajo/anaconda3/envs/geo_env/lib/python3.10/site-packages/osmnx/geometries.py:787: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   for merged_outer_linestring in list(merged_outer_linestrings):
# /home/yoviajo/anaconda3/envs/geo_env/lib/python3.10/site-packages/osmnx/geometries.py:787: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for merged_outer_linestring in list(merged_outer_linestrings):
# /home/yoviajo/anaconda3/envs/geo_env/lib/python3.10/site-packages/osmnx/utils_geo.py:374: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for poly in multipoly:
# /home/yoviajo/anaconda3/envs/geo_env/lib/python3.10/site-packages/prettymaps/fetch.py:222: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   multipolys = reduce(lambda x,y: x+y, [list(x) for x in multipolys]) if len(multipolys) > 0 else []
# /home/yoviajo/anaconda3/envs/geo_env/lib/python3.10/site-packages/prettymaps/fetch.py:222: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   multipolys = reduce(lambda x,y: x+y, [list(x) for x in multipolys]) if len(multipolys) > 0 else []
# /home/yoviajo/anaconda3/envs/geo_env/lib/python3.10/site-packages/osmnx/utils_geo.py:280: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for polygon in geometry:
# /home/yoviajo/anaconda3/envs/geo_env/lib/python3.10/site-packages/osmnx/utils_geo.py:280: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for polygon in geometry:
# /home/yoviajo/anaconda3/envs/geo_env/lib/python3.10/site-packages/osmnx/utils_geo.py:374: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for poly in multipoly:
# /home/yoviajo/anaconda3/envs/geo_env/lib/python3.10/site-packages/prettymaps/draw.py:109: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   layers = dict(zip(k, v))
# /home/yoviajo/anaconda3/envs/geo_env/lib/python3.10/site-packages/descartes/patch.py:62: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   vertices = concatenate([
# /home/yoviajo/anaconda3/envs/geo_env/lib/python3.10/site-packages/prettymaps/draw.py:77: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for shape in shapes:
# /home/yoviajo/anaconda3/envs/geo_env/lib/python3.10/site-packages/descartes/patch.py:64: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   [asarray(r)[:, :2] for r in t.interiors])
